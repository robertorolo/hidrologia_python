# %%
from hydro import *

# %%
file = 'dados/vazoes_C_86420000.csv'

# %%
s1 = Station(file)

# %%
s1.data.head()
# Out:
#    EstacaoCodigo NivelConsistencia        Data  Hora MediaDiaria  \
# 0       86420000             Bruto  01/04/2020   NaN         Sim
# 1       86420000             Bruto  01/03/2020   NaN         Sim
# 2       86420000             Bruto  01/02/2020   NaN         Sim
# 3       86420000             Bruto  01/01/2020   NaN         Sim
# 4       86420000             Bruto  01/12/2019   NaN         Sim
#
#   MetodoObtencaoVazoes Maxima Minima  Media  DiaMaxima  ...  Vazao22Status  \
# 0      Curvadedescarga  1,143   0,16  0,395        7.0  ...           Real
# 1      Curvadedescarga  0,917  0,235  0,477        1.0  ...           Real
# 2      Curvadedescarga  3,491  0,588  1,142       26.0  ...           Real
# 3      Curvadedescarga  4,325  1,223  1,583       28.0  ...           Real
# 4      Curvadedescarga  3,691  1,223  2,552        1.0  ...           Real
#
#    Vazao23Status  Vazao24Status  Vazao25Status  Vazao26Status  Vazao27Status  \
# ...
