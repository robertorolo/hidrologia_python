# %%
import ler_chuvas
import ler_vazoes

# %%
chuvas = 'dados/chuvas_C_03052010.csv'
vazoes = 'dados/vazoes_T_86160000.txt'

# %%
s_pluvi = ler_chuvas.Station(chuvas)

# %%
s_pluvi.data.head()
# Out:
#    EstacaoCodigo NivelConsistencia        Data TipoMedicaoChuvas Maxima  \
# 0        3052010             Bruto  01/05/2020       Pluviômetro   51,3
# 1        3052010             Bruto  01/04/2020       Pluviômetro   43,7
# 2        3052010             Bruto  01/03/2020       Pluviômetro   23,9
# 3        3052010             Bruto  01/02/2020       Pluviômetro   22,3
# 4        3052010             Bruto  01/01/2020       Pluviômetro   72,0
#
#    Total  DiaMaxima  NumDiasDeChuva  MaximaStatus  TotalStatus  ...  \
# 0  130,2         22               5             1            1  ...
# 1   55,8          2               2             1            1  ...
# 2   29,4         18               3             1            1  ...
# 3   33,7          1               4             1            1  ...
# 4  183,9          1               6             1            1  ...
#
#    Chuva22Status Chuva23Status  Chuva24Status Chuva25Status Chuva26Status  \
# ...

# %%
s_fluvi = ler_vazoes.Station(vazoes)

# %%
s_fluvi.data.head()
# Out:
#    EstacaoCodigo NivelConsistencia        Data  Hora MediaDiaria  \
# 0       86160000             Bruto  01/07/2020   NaN         Sim
# 1       86160000             Bruto  01/06/2020   NaN         Sim
# 2       86160000             Bruto  01/05/2020   NaN         Sim
# 3       86160000             Bruto  01/03/2020   NaN         Sim
# 4       86160000             Bruto  01/02/2020   NaN         Sim
#
#   MetodoObtencaoVazoes   Maxima  Minima    Media  DiaMaxima  ...  \
# 0      Curvadedescarga  778,226  20,172  134,138       12.0  ...
# 1      Curvadedescarga   95,729   0,235     6,14       30.0  ...
# 2      Curvadedescarga      NaN     NaN      NaN        NaN  ...
# 3      Curvadedescarga    8,392   0,235    1,634        1.0  ...
# 4      Curvadedescarga   17,703   1,262    4,289       27.0  ...
#
#    Vazao22Status  Vazao23Status  Vazao24Status  Vazao25Status Vazao26Status  \
# 0           Real           Real           Real           Real          Real
# ...
