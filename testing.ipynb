# %%
import vazoes

# %%
base = vazoes.Estacao('dados/vazoes/vazoes_C_70500000.csv')
e1 = vazoes.Estacao('dados/vazoes/vazoes_C_70100000.csv')
e2 = vazoes.Estacao('dados/vazoes/vazoes_C_70300000.csv')
e3 = vazoes.Estacao('dados/vazoes/vazoes_C_86160000.csv')

# %%
base.data.head()
# Out:
#    EstacaoCodigo NivelConsistencia        Data  Hora MediaDiaria  \
# 0       70500000             Bruto  01/08/2020   NaN         Sim
# 1       70500000             Bruto  01/07/2020   NaN         Sim
# 2       70500000             Bruto  01/06/2020   NaN         Sim
# 3       70500000             Bruto  01/05/2020   NaN         Sim
# 4       70500000             Bruto  01/04/2020   NaN         Sim
#
#   MetodoObtencaoVazoes   Maxima Minima   Media  DiaMaxima  ...  Vazao22Status  \
# 0      Curvadedescarga  138,103  4,252  16,296       15.0  ...           Real
# 1      Curvadedescarga  141,355  7,508  29,344        8.0  ...           Real
# 2      Curvadedescarga      NaN    NaN     NaN        NaN  ...            NaN
# 3      Curvadedescarga      NaN    NaN     NaN        NaN  ...         Branco
# 4      Curvadedescarga      NaN    NaN     NaN        NaN  ...         Branco
#
#    Vazao23Status  Vazao24Status  Vazao25Status  Vazao26Status  Vazao27Status  \
# ...

# %%
base.data.columns
# Out:
# Index(['EstacaoCodigo', 'NivelConsistencia', 'Data', 'Hora', 'MediaDiaria',
#        'MetodoObtencaoVazoes', 'Maxima', 'Minima', 'Media', 'DiaMaxima',
#        'DiaMinima', 'MaximaStatus', 'MinimaStatus', 'MediaStatus',
#        'MediaAnual', 'MediaAnualStatus', 'Vazao01', 'Vazao02', 'Vazao03',
#        'Vazao04', 'Vazao05', 'Vazao06', 'Vazao07', 'Vazao08', 'Vazao09',
#        'Vazao10', 'Vazao11', 'Vazao12', 'Vazao13', 'Vazao14', 'Vazao15',
#        'Vazao16', 'Vazao17', 'Vazao18', 'Vazao19', 'Vazao20', 'Vazao21',
#        'Vazao22', 'Vazao23', 'Vazao24', 'Vazao25', 'Vazao26', 'Vazao27',
#        'Vazao28', 'Vazao29', 'Vazao30', 'Vazao31', 'Vazao01Status',
#        'Vazao02Status', 'Vazao03Status', 'Vazao04Status', 'Vazao05Status',
#        'Vazao06Status', 'Vazao07Status', 'Vazao08Status', 'Vazao09Status',
#        'Vazao10Status', 'Vazao11Status', 'Vazao12Status', 'Vazao13Status',
#        'Vazao14Status', 'Vazao15Status', 'Vazao16Status', 'Vazao17Status',
# ...

# %%
estacoes = vazoes.Estacoes(base, [e1, e2, e3])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-cbb64ad4d98a> in <module>
# ----> 1 estacoes = vazoes.Estacoes(base, [e1, e2, e3])
#
# ~\Documents\GitHub\curva_de_permanencia\vazoes.py in __init__(self, base, estacao_lts)
#      88         for idx, row in datavazao.iterrows():
#      89             for e in estacoes:
# ---> 90                 datavazao[e.data.code] = float('nan')
#      91                 anomes = read_date(e.data['Data'])
#      92
#
# ~\anaconda3\envs\drh\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5137             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5138                 return self[name]
# -> 5139             return object.__getattribute__(self, name)
#    5140
#    5141     def __setattr__(self, name: str, value) -> None:
#
# ...

# %%
base.data[['Media', 'Vazao01', 'Vazao02', 'Vazao03',
       'Vazao04', 'Vazao05', 'Vazao06', 'Vazao07', 'Vazao08', 'Vazao09',
       'Vazao10', 'Vazao11', 'Vazao12', 'Vazao13', 'Vazao14', 'Vazao15',
       'Vazao16', 'Vazao17', 'Vazao18', 'Vazao19', 'Vazao20', 'Vazao21',
       'Vazao22', 'Vazao23', 'Vazao24', 'Vazao25', 'Vazao26', 'Vazao27',
       'Vazao28', 'Vazao29', 'Vazao30', 'Vazao31']].head(30)
# Out:
#      Media  Vazao01  Vazao02  Vazao03 Vazao04  Vazao05 Vazao06 Vazao07  \
# 0   16,296    9,646    9,153     8,67   7,964    7,508   7,062   6,626
# 1   29,344   21,877   16,954   17,898  39,029   22,223  48,541  82,925
# 2      NaN      NaN      NaN      NaN     NaN      NaN   4,252   4,618
# 3      NaN      NaN      NaN      NaN     NaN      NaN     NaN     NaN
# 4      NaN      NaN      NaN      NaN     NaN      NaN     NaN   0,376
# 5      NaN    3,388    2,908    2,605   2,038    1,775   1,527   1,294
# 6      NaN    0,376     0,31    0,524   4,252    2,174   1,409   2,174
# 7    2,006    0,781    0,691    0,605   0,605    0,524   0,448   0,376
# 8    3,039    2,755    2,605    2,314   2,038    1,905   1,775   1,649
# 9   20,214   36,464   22,223   14,828  11,992  201,655  74,355   33,56
# 10  13,913    1,409    2,314    3,724   2,605    4,618   9,398  12,818
# 11    3,06    2,908    2,314    2,038   1,775    1,649   2,605   7,735
# ...
